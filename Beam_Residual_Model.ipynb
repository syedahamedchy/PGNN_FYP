# %% [markdown]
# Import Relevant Libraries

# %%
import jax
import jax.numpy as jnp
import numpy as np
from numpy import *
import pandas as pd
from jax.experimental.ode import odeint
import matplotlib.pyplot as plt
from functools import partial
from jax.experimental import stax
from jax.experimental import optimizers
import matplotlib.pyplot as plt
from matplotlib.patches import Circle
from jax.lib import xla_bridge
from google.colab import drive, files

# %% [markdown]
# Get Training and Test Data

# %%
drive.mount('/content/drive')

# Get training dataset:
with open('/content/drive/My Drive/Colab Notebooks/FYP/Data/Cam2_sinus_6.8Hz_700mV/x_smoothed.csv', newline='') as csvfile:
  df = pd.read_csv(csvfile, delimiter=',')

L = (0.3/2210)

raw = np.array(df['19'])
t_train = np.arange(len(raw), dtype=np.float32) 
x_train_mean = raw.mean(axis=0)
x_train_std = 1
# x_train_std = raw.std(axis=0)
x_train = ((raw - x_train_mean) / x_train_std)*L
xdot_train = np.gradient(x_train, t_train)
xdotdot_train = np.gradient(xdot_train, t_train)

with open('/content/drive/My Drive/Colab Notebooks/FYP/Data/Cam2_sinus_6.8Hz_700mV/y_smoothed.csv', newline='') as csvfile:
  df = pd.read_csv(csvfile, delimiter=',')

raw = np.array(df['19'])
y_train_mean = raw.mean(axis=0)
y_train_std = 1
# y_train_std = raw.std(axis=0)
y_train = ((raw - y_train_mean) / y_train_std)*L
ydot_train = np.gradient(y_train, t_train)
ydotdot_train = np.gradient(ydot_train, t_train)

x_train = np.stack((x_train, y_train, xdot_train, ydot_train), axis=1)
xt_train = np.stack((xdot_train, ydot_train, xdotdot_train, ydotdot_train), axis=1)

# Get testing dataset:
with open('/content/drive/My Drive/Colab Notebooks/FYP/Data/Cam2_sinus_6.8Hz_400mV/x_smoothed.csv', newline='') as csvfile:
  df = pd.read_csv(csvfile, delimiter=',')

raw = np.array(df['19'])
t_test = np.arange(len(raw), dtype=np.float32) 
x_test_mean = raw.mean(axis=0)
x_test_std = 1
# x_test_std = raw.std(axis=0)
x_test = ((raw - x_test_mean) / x_test_std)*L
xdot_test = np.gradient(x_test, t_test)
xdotdot_test = np.gradient(xdot_test, t_test)

with open('/content/drive/My Drive/Colab Notebooks/FYP/Data/Cam2_sinus_6.8Hz_400mV/y_smoothed.csv', newline='') as csvfile:
  df = pd.read_csv(csvfile, delimiter=',')

raw = np.array(df['19'])
y_test_mean = raw.mean(axis=0)
y_test_std = 1
# y_test_std = raw.std(axis=0)
y_test = ((raw - y_test_mean) / y_test_std)*L
ydot_test = np.gradient(y_test, t_test)
ydotdot_test = np.gradient(ydot_test, t_test)

x_test = np.stack((x_test, y_test, xdot_test, ydot_test), axis=1)
xt_test = np.stack((xdot_test, ydot_test, xdotdot_test, ydotdot_test), axis=1)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Define Relevant Functions

# %%
# Note that the multiplication with 0.003 is to scale these properties with the time scales that the data is in. 
w1 = 31.09784*0.003
# w1= 6.8*2*(np.pi)*0.003

# %%
# Residual Model
def equation_of_motion(NN, state, t=None):
  q, q_t = jnp.split(state, 2)
  q_tt = - ((w1**2)*q) + jax.grad(NN)(q, q_t) # - ((2*zeta*w1)*q_t) 
  # Hence the final term represents both the force input and the nonlinearities
  return jnp.concatenate([q_t, q_tt])

# Use the odeint to solve the NN modelled system.
def solve_NN(NN, initial_state, **kwargs):
  @partial(jax.jit, backend='cpu')
  def f(initial_state):
    return odeint(partial(equation_of_motion, NN),
                  initial_state, **kwargs)
  return f(initial_state)

# Ensure that all inputs are normalised to only vary between -1 and 1. 
def normalise(state):
  return jnp.concatenate([state[:2], state[2:]])
# def normalise(state):
#   return jnp.concatenate([(state[:2] + 1) % (2) - 1, state[2:]])

# Define 4th order Runge-Kutta method for integration of losses. 
def rk4_step(f, x, t, h):
  k1 = h * f(x, t)
  k2 = h * f(x + k1/2, t + h/2)
  k3 = h * f(x + k2/2, t + h/2)
  k4 = h * f(x + k3, t + h)
  return x + 1/6 * (k1 + 2 * k2 + 2 * k3 + k4)

# %% [markdown]
# Initialise Neural Network

# %%
def learned_NN(params):
  def NN(q, q_t):
    assert q.shape == (2,)
    state = normalise(jnp.concatenate([q, q_t]))
    return jnp.squeeze(nn_forward_fn(params, state), axis=-1)
  return NN

# Now we define the loss function of the model. In our case it is the Mean 
# Squared Error between the predicted and the observed accelerations. 
@jax.jit
def loss(params, batch, time_step=None):
  state, targets = batch
  if time_step is not None:
    f = partial(equation_of_motion, learned_NN(params))
    preds = jax.vmap(partial(rk4_step, f, t=0.0, h=time_step))(state)
  else:
    preds = jax.vmap(partial(equation_of_motion, learned_NN(params)))(state)
  return jnp.mean((preds - targets) ** 2)

# Set up the Neural Network. 
init_random_params, nn_forward_fn = stax.serial(
    stax.Dense(128),
    stax.Softplus,
    stax.Dense(128),
    stax.Softplus,
    stax.Dense(1),
)

@jax.jit
def update_derivative(i, opt_state, batch):
  params = get_params(opt_state)
  return opt_update(i, jax.grad(loss)(params, batch, None), opt_state)

# Initialise the parametes in the neural network to be random. 
rng = jax.random.PRNGKey(0)
_, init_params = init_random_params(rng, (-1, 4))

# Define the training process. 
batch_size = 100
test_every = 10
num_batches = 1500 # Further training seems to overfit the model. 
# Change no. batches to 2500 and batch size to 10 if you are training with multiple experimental datasets. 

train_losses = []
test_losses = []

# Define the training optimiser.
opt_init, opt_update, get_params = optimizers.adam(
    lambda t: jnp.select([t < batch_size*(num_batches//3),
                          t < batch_size*(2*num_batches//3),
                          t > batch_size*(2*num_batches//3)],
                         [1e-3, 3e-4, 1e-4]))
opt_state = opt_init(init_params)

# %% [markdown]
# Train the Neural Network

# %%
# Perform training process. 
for iteration in range(batch_size*num_batches + 1):
  if iteration % batch_size == 0:
    params = get_params(opt_state)
    train_loss = loss(params, (x_train, xt_train))
    train_losses.append(train_loss)
    test_loss = loss(params, (x_test, xt_test))
    test_losses.append(test_loss)
    if iteration % (batch_size*test_every) == 0:
      print(f"iteration={iteration}, train_loss={train_loss:.6f}, test_loss={test_loss:.6f}")
  opt_state = update_derivative(iteration, opt_state, (x_train, xt_train))

params = get_params(opt_state)
# Out:
# iteration=0, train_loss=0.000201, test_loss=0.000201
# iteration=1000, train_loss=0.000004, test_loss=0.000004
# iteration=2000, train_loss=0.000000, test_loss=0.000000
# iteration=3000, train_loss=0.000000, test_loss=0.000000
# iteration=4000, train_loss=0.000000, test_loss=0.000000
# iteration=5000, train_loss=0.000000, test_loss=0.000000
# iteration=6000, train_loss=0.000001, test_loss=0.000001
# iteration=7000, train_loss=0.000000, test_loss=0.000000
# iteration=8000, train_loss=0.000000, test_loss=0.000000
# iteration=9000, train_loss=0.000000, test_loss=0.000000
# iteration=10000, train_loss=0.000000, test_loss=0.000000
# iteration=11000, train_loss=0.000000, test_loss=0.000000
# iteration=12000, train_loss=0.000000, test_loss=0.000000
# iteration=13000, train_loss=0.000000, test_loss=0.000000
# iteration=14000, train_loss=0.000000, test_loss=0.000000
# iteration=15000, train_loss=0.000000, test_loss=0.000000
# iteration=16000, train_loss=0.000000, test_loss=0.000000
# iteration=17000, train_loss=0.000000, test_loss=0.000000
# iteration=18000, train_loss=0.000000, test_loss=0.000000
# iteration=19000, train_loss=0.000000, test_loss=0.000000
# iteration=20000, train_loss=0.000000, test_loss=0.000000
# iteration=21000, train_loss=0.000000, test_loss=0.000000
# iteration=22000, train_loss=0.000000, test_loss=0.000000
# iteration=23000, train_loss=0.000000, test_loss=0.000000
# iteration=24000, train_loss=0.000000, test_loss=0.000000
# iteration=25000, train_loss=0.000000, test_loss=0.000000
# iteration=26000, train_loss=0.000000, test_loss=0.000000
# iteration=27000, train_loss=0.000000, test_loss=0.000000
# iteration=28000, train_loss=0.000000, test_loss=0.000000
# iteration=29000, train_loss=0.000000, test_loss=0.000000
# iteration=30000, train_loss=0.000000, test_loss=0.000000
# iteration=31000, train_loss=0.000000, test_loss=0.000000
# iteration=32000, train_loss=0.000000, test_loss=0.000000
# iteration=33000, train_loss=0.000000, test_loss=0.000000
# iteration=34000, train_loss=0.000000, test_loss=0.000000
# iteration=35000, train_loss=0.000000, test_loss=0.000000
# iteration=36000, train_loss=0.000000, test_loss=0.000000
# iteration=37000, train_loss=0.000000, test_loss=0.000000
# iteration=38000, train_loss=0.000000, test_loss=0.000000
# iteration=39000, train_loss=0.000000, test_loss=0.000000
# iteration=40000, train_loss=0.000000, test_loss=0.000000
# iteration=41000, train_loss=0.000000, test_loss=0.000000
# iteration=42000, train_loss=0.000000, test_loss=0.000000
# iteration=43000, train_loss=0.000000, test_loss=0.000000
# iteration=44000, train_loss=0.000000, test_loss=0.000000
# iteration=45000, train_loss=0.000000, test_loss=0.000000
# iteration=46000, train_loss=0.000000, test_loss=0.000000
# iteration=47000, train_loss=0.000000, test_loss=0.000000
# iteration=48000, train_loss=0.000000, test_loss=0.000000
# iteration=49000, train_loss=0.000000, test_loss=0.000000
# iteration=50000, train_loss=0.000000, test_loss=0.000000
# iteration=51000, train_loss=0.000000, test_loss=0.000000
# iteration=52000, train_loss=0.000000, test_loss=0.000000
# iteration=53000, train_loss=0.000000, test_loss=0.000000
# iteration=54000, train_loss=0.000000, test_loss=0.000000
# iteration=55000, train_loss=0.000000, test_loss=0.000000
# iteration=56000, train_loss=0.000000, test_loss=0.000000
# iteration=57000, train_loss=0.000000, test_loss=0.000000
# iteration=58000, train_loss=0.000000, test_loss=0.000000
# iteration=59000, train_loss=0.000000, test_loss=0.000000
# iteration=60000, train_loss=0.000000, test_loss=0.000000
# iteration=61000, train_loss=0.000000, test_loss=0.000000
# iteration=62000, train_loss=0.000000, test_loss=0.000000
# iteration=63000, train_loss=0.000000, test_loss=0.000000
# iteration=64000, train_loss=0.000000, test_loss=0.000000
# iteration=65000, train_loss=0.000000, test_loss=0.000000
# iteration=66000, train_loss=0.000000, test_loss=0.000000
# iteration=67000, train_loss=0.000000, test_loss=0.000000
# iteration=68000, train_loss=0.000000, test_loss=0.000000
# iteration=69000, train_loss=0.000000, test_loss=0.000000
# iteration=70000, train_loss=0.000000, test_loss=0.000000
# iteration=71000, train_loss=0.000000, test_loss=0.000000
# iteration=72000, train_loss=0.000000, test_loss=0.000000
# iteration=73000, train_loss=0.000000, test_loss=0.000000
# iteration=74000, train_loss=0.000000, test_loss=0.000000
# iteration=75000, train_loss=0.000000, test_loss=0.000000
# iteration=76000, train_loss=0.000000, test_loss=0.000000
# iteration=77000, train_loss=0.000000, test_loss=0.000000
# iteration=78000, train_loss=0.000000, test_loss=0.000000
# iteration=79000, train_loss=0.000000, test_loss=0.000000
# iteration=80000, train_loss=0.000000, test_loss=0.000000
# iteration=81000, train_loss=0.000000, test_loss=0.000000
# iteration=82000, train_loss=0.000000, test_loss=0.000000
# iteration=83000, train_loss=0.000000, test_loss=0.000000
# iteration=84000, train_loss=0.000000, test_loss=0.000000
# iteration=85000, train_loss=0.000000, test_loss=0.000000
# iteration=86000, train_loss=0.000000, test_loss=0.000000
# iteration=87000, train_loss=0.000000, test_loss=0.000000
# iteration=88000, train_loss=0.000000, test_loss=0.000000
# iteration=89000, train_loss=0.000000, test_loss=0.000000
# iteration=90000, train_loss=0.000000, test_loss=0.000000
# iteration=91000, train_loss=0.000000, test_loss=0.000000
# iteration=92000, train_loss=0.000000, test_loss=0.000000
# iteration=93000, train_loss=0.000000, test_loss=0.000000
# iteration=94000, train_loss=0.000000, test_loss=0.000000
# iteration=95000, train_loss=0.000000, test_loss=0.000000
# iteration=96000, train_loss=0.000000, test_loss=0.000000
# iteration=97000, train_loss=0.000000, test_loss=0.000000
# iteration=98000, train_loss=0.000000, test_loss=0.000000
# iteration=99000, train_loss=0.000000, test_loss=0.000000
# iteration=100000, train_loss=0.000000, test_loss=0.000000
# iteration=101000, train_loss=0.000000, test_loss=0.000000
# iteration=102000, train_loss=0.000000, test_loss=0.000000
# iteration=103000, train_loss=0.000000, test_loss=0.000000
# iteration=104000, train_loss=0.000000, test_loss=0.000000
# iteration=105000, train_loss=0.000000, test_loss=0.000000
# iteration=106000, train_loss=0.000000, test_loss=0.000000
# iteration=107000, train_loss=0.000000, test_loss=0.000000
# iteration=108000, train_loss=0.000000, test_loss=0.000000
# iteration=109000, train_loss=0.000000, test_loss=0.000000
# iteration=110000, train_loss=0.000000, test_loss=0.000000
# iteration=111000, train_loss=0.000000, test_loss=0.000000
# iteration=112000, train_loss=0.000000, test_loss=0.000000
# iteration=113000, train_loss=0.000000, test_loss=0.000000
# iteration=114000, train_loss=0.000000, test_loss=0.000000
# iteration=115000, train_loss=0.000000, test_loss=0.000000
# iteration=116000, train_loss=0.000000, test_loss=0.000000
# iteration=117000, train_loss=0.000000, test_loss=0.000000
# iteration=118000, train_loss=0.000000, test_loss=0.000000
# iteration=119000, train_loss=0.000000, test_loss=0.000000
# iteration=120000, train_loss=0.000000, test_loss=0.000000
# iteration=121000, train_loss=0.000000, test_loss=0.000000
# iteration=122000, train_loss=0.000000, test_loss=0.000000
# iteration=123000, train_loss=0.000000, test_loss=0.000000
# iteration=124000, train_loss=0.000000, test_loss=0.000000
# iteration=125000, train_loss=0.000000, test_loss=0.000000
# iteration=126000, train_loss=0.000000, test_loss=0.000000
# iteration=127000, train_loss=0.000000, test_loss=0.000000
# iteration=128000, train_loss=0.000000, test_loss=0.000000
# iteration=129000, train_loss=0.000000, test_loss=0.000000
# iteration=130000, train_loss=0.000000, test_loss=0.000000
# iteration=131000, train_loss=0.000000, test_loss=0.000000
# iteration=132000, train_loss=0.000000, test_loss=0.000000
# iteration=133000, train_loss=0.000000, test_loss=0.000000
# iteration=134000, train_loss=0.000000, test_loss=0.000000
# iteration=135000, train_loss=0.000000, test_loss=0.000000
# iteration=136000, train_loss=0.000000, test_loss=0.000000
# iteration=137000, train_loss=0.000000, test_loss=0.000000
# iteration=138000, train_loss=0.000000, test_loss=0.000000
# iteration=139000, train_loss=0.000000, test_loss=0.000000
# iteration=140000, train_loss=0.000000, test_loss=0.000000
# iteration=141000, train_loss=0.000000, test_loss=0.000000
# iteration=142000, train_loss=0.000000, test_loss=0.000000
# iteration=143000, train_loss=0.000000, test_loss=0.000000
# iteration=144000, train_loss=0.000000, test_loss=0.000000
# iteration=145000, train_loss=0.000000, test_loss=0.000000
# iteration=146000, train_loss=0.000000, test_loss=0.000000
# iteration=147000, train_loss=0.000000, test_loss=0.000000
# iteration=148000, train_loss=0.000000, test_loss=0.000000
# iteration=149000, train_loss=0.000000, test_loss=0.000000
# iteration=150000, train_loss=0.000000, test_loss=0.000000

# %%
plt.figure(figsize=(8, 3.5), dpi=120)
epochs = np.linspace(0, ((batch_size/(175))*num_batches), (num_batches + 1))
plt.plot(epochs, train_losses, label='Train Loss')
plt.plot(epochs, test_losses, label='Test Loss')
plt.yscale('log')
plt.ylim(None, 200)
plt.title('Losses over Training')
plt.xlabel("Epoch Number")
plt.ylabel("Loss (Mean Squared Error)")
plt.legend()
plt.show()

# %% [markdown]
# Make Predictions Using Trained Model

# %%
# Compare to training dataset.
experimental = x_train
N = len(x_train[:, 0])
time = np.linspace(0, N, N)
X0 = x_train[0, :]
predicted = jax.device_get(solve_NN(learned_NN(params), X0, t=time))
# predicted = solve_lagrangian(learned_lagrangian(params), X0, t=time)
time = time*0.003

# De-normalise the data and scale it to real-life. 
experimental[:, 0] = (experimental[:, 0] * x_train_std) #+ x_train_mean
experimental[:, 1] = (experimental[:, 1] * y_train_std) #+ y_train_mean
model = np.empty_like(predicted)
model_x = (predicted[:, 0] * x_train_std) #+ x_train_mean
model_y = (predicted[:, 1] * y_train_std) #+ y_train_mean

figure, axis = plt.subplots(1, 2, figsize=(16,5))
plt.rc('xtick', labelsize= 16)
plt.rc('ytick', labelsize= 16)

axis[0].set_title("Experimental vs LNN: Y-Displacement (Training Data)", fontsize=16)
axis[0].plot(time, experimental[:, 1]*1000, 'g-', label=r'Exact Displacement')
axis[0].plot(time, model_y*1000, 'r--', label=r'LNN Predicted Displacement')
axis[0].set_xlabel("Time (s)", fontsize=16)
axis[0].set_ylabel("Displacement (mm)", fontsize=16)

axis[1].set_title("Experimental vs LNN: X-Displacement (Training Data)", fontsize=16)
axis[1].plot(time, experimental[:, 0]*1000, 'g-', label=r'Exact Displacement')
axis[1].plot(time, model_x*1000, 'r--', label=r'LNN Predicted Displacement')
axis[1].set_xlabel("Time (s)", fontsize=16)
axis[1].set_ylabel("Displacement (mm)", fontsize=16)
axis[1].legend(fontsize=14, loc='lower right')

plt.show()

print('Absolute Performance:')

E2_error = 0
for i in range(0, len(time)):
  E2_error = E2_error + (abs((experimental[i, 1] - model_y[i])**2))
E2_error = (E2_error / len(model_y))**0.5
print("RMS Error in Y: ", E2_error)

E2_error = 0
for i in range(0, len(time)):
  E2_error = E2_error + (abs((experimental[i, 0] - model_x[i])**2))
E2_error = (E2_error / len(model_x))**0.5
print("RMS Error in X: ", E2_error)

print('Normalised Performance:')
# Normalise the results so that their errors can be compared. 
experimental[:, 0] = experimental[:, 0]/np.std(experimental[:, 0])
experimental[:, 1] = experimental[:, 1]/np.std(experimental[:, 1])
model_x = model_x/np.std(model_x)
model_y = model_y/np.std(model_y)

E2_error = 0
for i in range(0, len(time)):
  E2_error = E2_error + (abs((experimental[i, 1] - model_y[i])**2))
E2_error = (E2_error / len(model_y))**0.5
print("RMS Error in Y: ", E2_error)

E2_error = 0
for i in range(0, len(time)):
  E2_error = E2_error + (abs((experimental[i, 0] - model_x[i])**2))
E2_error = (E2_error / len(model_x))**0.5
print("RMS Error in X: ", E2_error)
# Out:
# Absolute Performance:
# RMS Error in Y:  0.0005829214289602314
# RMS Error in X:  0.0008238249883637086
# Normalised Performance:
# RMS Error in Y:  0.0287773369486535
# RMS Error in X:  1.3561458250786131

# %%
# # Get an error metric.
# def R2(true, predicted):
#   correlation_matrix = np.corrcoef(true, predicted)
#   correlation_xy = correlation_matrix[0,1]
#   return correlation_xy**2

# # Compare to training dataset.
# experimental = x_train
# N = len(x_train[:, 0])
# time = np.linspace(0, N, N)
# X0 = x_train[0, :]
# predicted = jax.device_get(solve_NN(learned_NN(params), X0, t=time))
# # predicted = solve_lagrangian(learned_lagrangian(params), X0, t=time)
# time = time*0.003

# # De-normalise the data and scale it to real-life. 
# experimental[:, 0] = (experimental[:, 0] * x_train_std) #+ x_train_mean
# experimental[:, 1] = (experimental[:, 1] * y_train_std) #+ y_train_mean
# model = np.empty_like(predicted)
# model_x = (predicted[:, 0] * x_train_std) #+ x_train_mean
# model_y = (predicted[:, 1] * y_train_std) #+ y_train_mean

# print("R-Squared Value for Y-Displacement: ", R2(model_y, experimental[:,1]))
# print("R-Squared Value for Y-Displacement: ", R2(model_x, experimental[:,0]))

# # Plot them alongside. 
# figure, axis = plt.subplots(2, 1, figsize=(8,12))

# axis[0].set_title("Experimental vs LNN: Y-Displacement (Training Data)", fontsize=16)
# axis[0].plot(time, experimental[:, 1]*1000, 'g-', label=r'Exact Displacement')
# axis[0].plot(time, model_y*1000, 'r--', label=r'LNN Predicted Displacement')
# axis[0].set_xlabel("Time (s)", fontsize=16)
# axis[0].set_ylabel("Displacement (mm)", fontsize=16)
# plt.rc('xtick', labelsize='LARGE')

# axis[1].set_title("Experimental vs LNN: X-Displacement (Training Data)", fontsize=16)
# axis[1].plot(time, experimental[:, 0]*1000, 'g-', label=r'Exact Displacement')
# axis[1].plot(time, model_x*1000, 'r--', label=r'LNN Predicted Displacement')
# axis[1].set_xlabel("Time (s)", fontsize=16)
# axis[1].set_ylabel("Displacement (mm)", fontsize=16)
# axis[1].legend(fontsize=14, loc='lower right')
# plt.rc('xtick', labelsize='LARGE')

# print('Absolute Performance:')

# E2_error = 0
# for i in range(0, len(time)):
#   E2_error = E2_error + (abs((experimental[i, 1] - model_y[i])**2))
# E2_error = (E2_error / len(model_y))**0.5
# print("RMS Error in Y: ", E2_error)

# E2_error = 0
# for i in range(0, len(time)):
#   E2_error = E2_error + (abs((experimental[i, 0] - model_x[i])**2))
# E2_error = (E2_error / len(model_x))**0.5
# print("RMS Error in X: ", E2_error)

# print('Normalised Performance:')
# # Normalise the results so that their errors can be compared. 
# experimental[:, 0] = experimental[:, 0]/np.std(experimental[:, 0])
# experimental[:, 1] = experimental[:, 1]/np.std(experimental[:, 1])
# model_x = model_x/np.std(model_x)
# model_y = model_y/np.std(model_y)

# E2_error = 0
# for i in range(0, len(time)):
#   E2_error = E2_error + (abs((experimental[i, 1] - model_y[i])**2))
# E2_error = (E2_error / len(model_y))**0.5
# print("RMS Error in Y: ", E2_error)

# E2_error = 0
# for i in range(0, len(time)):
#   E2_error = E2_error + (abs((experimental[i, 0] - model_x[i])**2))
# E2_error = (E2_error / len(model_x))**0.5
# print("RMS Error in X: ", E2_error)

# %%
# # Compare to testing dataset. 
# experimental = x_test
# N = len(x_test[:, 0])
# time = np.linspace(0, N, N)
# X0 = x_test[0, :]
# predicted = jax.device_get(solve_NN(learned_NN(params), X0, t=time))
# time = time*0.003

# # De-normalise the data and scale it to real-life. 
# experimental[:, 0] = (experimental[:, 0] * x_test_std) #+ x_train_mean
# experimental[:, 1] = (experimental[:, 1] * y_test_std) #+ y_train_mean
# model = np.empty_like(predicted)
# model_x = (predicted[:, 0] * x_test_std) #+ x_train_mean
# model_y = (predicted[:, 1] * y_test_std) #+ y_train_mean

# print("R-Squared Value for Y-Displacement: ", R2(model_y, experimental[:,1]))
# print("R-Squared Value for Y-Displacement: ", R2(model_x, experimental[:,0]))

# # Plot them alongside. 
# figure, axis = plt.subplots(2, 1, figsize=(10,15))

# axis[0].set_title("Experimental vs LNN: Y-Displacement (Testing Data)", fontsize=16)
# axis[0].plot(time, experimental[:, 1]*1000, 'g-', label=r'Exact Displacement')
# axis[0].plot(time, model_y*1000, 'r--', label=r'LNN Predicted Displacement')
# axis[0].set_xlabel("Time (s)", fontsize=16)
# axis[0].set_ylabel("Displacement (mm)", fontsize=16)
# axis[0].legend(fontsize=14, loc='lower right')
# plt.rc('xtick', labelsize='LARGE')

# axis[1].set_title("Experimental vs LNN: X-Displacement (Testing Data)", fontsize=16)
# axis[1].plot(time, experimental[:, 0]*1000, 'g-', label=r'Exact Displacement')
# axis[1].plot(time, model_x*1000, 'r--', label=r'LNN Predicted Displacement')
# axis[1].set_xlabel("Time (s)", fontsize=16)
# axis[1].set_ylabel("Displacement (mm)", fontsize=16)
# axis[1].legend(fontsize=14, loc='lower right')
# plt.rc('xtick', labelsize='LARGE')

# print('RMS Performance:')
# # Normalise the results so that their errors can be compared. 

# E2_error = 0
# for i in range(0, len(time)):
#   E2_error = E2_error + (abs((experimental[i, 1] - model_y[i])**2))
# E2_error = (E2_error / len(model_y))**0.5
# print("RMS Error in Y: ", E2_error)

# E2_error = 0
# for i in range(0, len(time)):
#   E2_error = E2_error + (abs((experimental[i, 0] - model_x[i])**2))
# E2_error = (E2_error / len(model_x))**0.5
# print("RMS Error in X: ", E2_error)

# print('Normalised RMS Performance:')
# # Normalise the results so that their errors can be compared. 
# experimental[:, 0] = experimental[:, 0]/np.std(experimental[:, 0])
# experimental[:, 1] = experimental[:, 1]/np.std(experimental[:, 1])
# model_x = model_x/np.std(model_x)
# model_y = model_y/np.std(model_y)

# E2_error = 0
# for i in range(0, len(time)):
#   E2_error = E2_error + (abs((experimental[i, 1] - model_y[i])**2))
# E2_error = (E2_error / len(model_y))**0.5
# print("RMS Error in Y: ", E2_error)

# E2_error = 0
# for i in range(0, len(time)):
#   E2_error = E2_error + (abs((experimental[i, 0] - model_x[i])**2))
# E2_error = (E2_error / len(model_x))**0.5
# print("RMS Error in X: ", E2_error)

# %%
# # Make predictions with testing dataset beyond the experimentally observed time period. 
# experimental = x_test
# N = len(x_test[:, 0])
# time = np.linspace(0, 4*N, 2*N)
# X0 = x_test[0, :]
# predicted = solve_NN(learned_NN(params), X0, t=time)
# time = time*0.003

# # De-normalise the data and scale it to real-life. 
# experimental[:, 0] = (experimental[:, 0] * x_test_std) 
# experimental[:, 1] = (experimental[:, 1] * y_test_std) 
# model = np.empty_like(predicted)
# model[:, 0] = (predicted[:, 0] * x_test_std) 
# model[:, 1] = (predicted[:, 1] * y_test_std) 

# # Plot them alongside. 
# figure, axis = plt.subplots(2, 1, figsize=(25,15))

# axis[0].set_title("Experimental vs LNN: Y-Displacement (Testing Data Extended)", fontsize=16)
# axis[0].plot(time[0:N], experimental[:, 1], 'g-', label=r'Exact Displacement')
# axis[0].plot(time, model[:, 1], 'r--', label=r'LNN Predicted Displacement')
# axis[0].set_xlabel("Time (s)", fontsize=16)
# axis[0].set_ylabel("Displacement (mm)", fontsize=16)
# axis[0].legend(fontsize=14, loc='lower right')
# plt.rc('xtick', labelsize='LARGE')

# axis[1].set_title("Experimental vs LNN: X-Displacement (Testing Data Extended)", fontsize=16)
# axis[1].plot(time[0:N], experimental[:, 0], 'g-', label=r'Exact Displacement')
# axis[1].plot(time, model[:, 0], 'r--', label=r'LNN Predicted Displacement')
# axis[1].set_xlabel("Time (s)", fontsize=16)
# axis[1].set_ylabel("Displacement (mm)", fontsize=16)
# axis[1].legend(fontsize=14, loc='lower right')
# plt.rc('xtick', labelsize='LARGE')
